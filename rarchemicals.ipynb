# %%
import os
from flask import Flask, render_template, abort
from google.colab.output import eval_js
import shutil # Import shutil for a more robust move

# --- STEP 1: CREATE DIRECTORIES ---
os.makedirs('templates', exist_ok=True)
os.makedirs('static', exist_ok=True)

# --- Move images to static directory ---
image_files = ['activated_alumina.jpg', 'chlorine_guard.jpg', 'catalyst_carriers.jpg']
for img_file in image_files:
    source_path = f'/content/{img_file}'
    destination_path = f'static/{img_file}'
    # Check if the file is in /content and not already in static
    if os.path.exists(source_path) and not os.path.exists(destination_path):
        try:
            shutil.move(source_path, destination_path)
        except Exception as e:
            print(f"Error moving {img_file}: {e}")

# --- STEP 2: DEFINE YOUR FILES ---
# This dictionary contains all the files you uploaded merged into one place.
html_files = {
    "layout.html": """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>RAR Chemicals | Industrial Excellence</title>
    <script src="https://cdn.tailwindcss.com"></script>
    <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@700;900&family=Inter:wght@400;600&display=swap" rel="stylesheet">
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body class="bg-slate-50">
    <header class="bg-black sticky top-0 z-[100] text-white border-bottom border-slate-800">
        <nav class="container mx-auto px-6 py-4 flex justify-between items-center">
            <a href="/" class="text-2xl font-black tracking-tighter" style="font-family: 'Montserrat';">
                RAR <span class="text-sky-500">CHEMICALS</span>
            </a>
            <ul class="hidden md:flex space-x-8 text-xs font-bold uppercase tracking-widest">
                <li><a href="/" class="hover:text-sky-400 transition">Home</a></li>
                <li><a href="/about" class="hover:text-sky-400 transition">About Us</a></li>
                <li><a href="/catalysts" class="hover:text-sky-400 transition">Catalysts</a></li>
                <li><a href="/contact" class="bg-sky-500 text-black px-4 py-2 rounded hover:bg-white transition">Contact</a></li>
            </ul>
        </nav>
    </header>
    <main>{% block content %}{% endblock %}</main>
    <footer class="py-10 bg-black text-center text-slate-500 text-[10px] uppercase tracking-[0.3em]">
        &copy; 2026 RAR Chemicals Pvt. Ltd. | Molecular Innovation
    </footer>
</body>
</html>
""",
    "index.html": """
{% extends "layout.html" %}
{% block content %}
<section class="py-24 bg-slate-50">
    <div class="container mx-auto px-6 grid grid-cols-1 lg:grid-cols-2 gap-12 items-center">
        <div>
            <h1 class="text-6xl font-black leading-tight mb-6" style="font-family: 'Montserrat';">RAR <br>CHEMICALS</h1>
            <p class="text-xl text-slate-600 mb-8 italic">"React & Refine: The standard in industrial adsorbents."</p>
            <div class="flex gap-4">
                <a href="/catalysts" class="px-8 py-4 bg-black text-white font-bold rounded hover:bg-slate-800 transition">View Catalysts</a>
                <a href="/about" class="px-8 py-4 border border-black font-bold rounded hover:bg-black hover:text-white transition">Our Story</a>
            </div>
        </div>
        <div class="bg-white p-10 shadow-xl border-t-4 border-black">
            <h3 class="text-5xl font-black mb-2">70%</h3>
            <p class="text-sm uppercase tracking-widest font-bold text-slate-400">Market Presence</p>
            <hr class="my-6">
            <p class="text-slate-500 font-light">Leading the EMEA region in molecular innovation and spent catalyst regeneration.</p>
        </div>
    </div>
</section>
{% endblock %}
""",
    "about.html": """
{% extends "layout.html" %}
{% block content %}
<section class="py-24 bg-white">
    <div class="container mx-auto px-6 max-w-4xl">
        <h1 class="text-4xl font-black mb-8 border-b-4 border-sky-500 inline-block" style="font-family: 'Montserrat';">About Us</h1>
        <p class="text-xl leading-relaxed text-slate-800 mb-6 font-semibold">RAR Chemicals Pvt. Ltd. is a premier manufacturer and supplier of high-performance industrial adsorbents.</p>
        <p class="text-lg leading-relaxed text-slate-600 mb-8">Specializing in Activated Alumina, Chlorine Guards, and Catalyst Carriers for the petrochemical and water treatment industries.</p>
    </div>
</section>
{% endblock %}
""",
    "catalysts.html": """
{% extends "layout.html" %}
{% block content %}
<section class="py-24">
    <div class="container mx-auto px-6 text-center">
        <h1 class="text-4xl font-black mb-16" style="font-family: 'Montserrat';">Our Specialized Products</h1>
        <div class="grid grid-cols-1 md:grid-cols-3 gap-12">
            <div class="bg-white rounded-2xl overflow-hidden shadow-lg border border-slate-200">
                <div class="h-64 bg-slate-200"><img src="{{ url_for('static', filename='activated_alumina.jpg') }}" class="object-cover w-full h-full"></div>
                <div class="p-8">
                    <h3 class="text-xl font-bold mb-4">Activated Alumina</h3>
                    <a href="/uses/alumina" class="inline-block w-full py-3 bg-black text-white font-bold rounded hover:bg-sky-600 transition">View Uses</a>
                </div>
            </div>
            <div class="bg-white rounded-2xl overflow-hidden shadow-lg border border-slate-200">
                <div class="h-64 bg-slate-200"><img src="{{ url_for('static', filename='chlorine_guard.jpg') }}" class="object-cover w-full h-full"></div>
                <div class="p-8">
                    <h3 class="text-xl font-bold mb-4">Chlorine Guards</h3>
                    <a href="/uses/chlorine" class="inline-block w-full py-3 bg-black text-white font-bold rounded hover:bg-sky-600 transition">View Uses</a>
                </div>
            </div>
            <div class="bg-white rounded-2xl overflow-hidden shadow-lg border border-slate-200">
                <div class="h-64 bg-slate-200"><img src="{{ url_for('static', filename='catalyst_carriers.jpg') }}" class="object-cover w-full h-full"></div>
                <div class="p-8">
                    <h3 class="text-xl font-bold mb-4">Catalyst Carriers</h3>
                    <a href="/uses/carriers" class="inline-block w-full py-3 bg-black text-white font-bold rounded hover:bg-sky-600 transition">View Uses</a>
                </div>
            </div>
        </div>
    </div>
</section>
{% endblock %}
""",
    "contact.html": """
{% extends "layout.html" %}
{% block content %}
<section class="py-24">
    <div class="container mx-auto px-6">
        <div class="flex flex-col md:flex-row bg-white rounded-3xl overflow-hidden shadow-2xl">
            <div class="md:w-1/2">
                <img src="{{ url_for('static', filename='contact_info.png') }}" alt="Contact" class="w-full h-full object-cover">
            </div>
            <div class="md:w-1/2 p-12 flex flex-col justify-center">
                <h2 class="text-4xl font-black mb-6" style="font-family: 'Montserrat';">Get in Touch</h2>
                <p class="text-slate-800 font-bold mb-2 uppercase text-xs text-sky-600">Headquarters</p>
                <p class="text-slate-800 font-bold mb-6">OFFICE NO. 3 TAKPADA MAKWANA ROAD, MUMBAI 400059.</p>
                <p class="text-slate-800 font-bold mb-2 uppercase text-xs text-sky-600">Email</p>
                <p class="text-slate-800 font-bold">rarchemicalspvtltd.in@gmail.com</p>
            </div>
        </div>
    </div>
</section>
{% endblock %}
""",
    "uses.html": """
{% extends "layout.html" %}
{% block content %}
<section class="py-24 container mx-auto px-6">
    <h1 class="text-4xl font-black mb-8" style="font-family: 'Montserrat';">{{ product.title }}</h1>
    <ul class="list-disc pl-6 space-y-4 text-lg text-slate-700">
        {% for point in product.points %}
        <li>{{ point }}</li>
        {% endfor %}
    </ul>
    <a href="/catalysts" class="mt-12 inline-block font-bold text-sky-600 hover:underline">← Back to Products</a>
</section>
{% endblock %}
"""
}

# Save HTML templates
for name, content in html_files.items():
    with open(f"templates/{name}", "w") as f:
        f.write(content.strip())

# Save CSS
with open("static/style.css", "w") as f:
    f.write(":root { --navy: #002347; } body { font-family: 'Inter', sans-serif; }")

# --- STEP 3: FLASK LOGIC ---
app = Flask(__name__)

# Data for the "View Uses" buttons
PRODUCT_DATA = {
    "alumina": {"title": "Activated Alumina Uses", "points": ["Air & Gas Drying", "Water Purification", "Fluoride Removal"]},
    "chlorine": {"title": "Chlorine Guard Uses", "points": ["Feedstock Purification", "Catalyst Protection", "Corrosion Prevention"]},
    "carriers": {"title": "Catalyst Carrier Uses", "points": ["Chemical Synthesis", "Process Support", "High Surface Area Reaction Medium"]}
}

@app.route('/')
def home(): return render_template('index.html')

@app.route('/about')
def about(): return render_template('about.html')

@app.route('/catalysts')
def catalysts(): return render_template('catalysts.html')

@app.route('/contact')
def contact(): return render_template('contact.html')

@app.route('/uses/<product_id>')
def uses(product_id):
    product = PRODUCT_DATA.get(product_id)
    if not product: abort(404)
    return render_template('uses.html', product=product)

# --- STEP 4: LAUNCH ---
print("WEBSITE LINK: " + eval_js("google.colab.kernel.proxyPort(5000)"))
if __name__ == '__main__':
    app.run(port=5000)
# Out:
# WEBSITE LINK: https://5000-m-s-4m54pb6jptx7-b.us-west1-2.prod.colab.dev
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [01/Mar/2026 16:04:07] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Mar/2026 16:04:07] "GET /static/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Mar/2026 16:04:09] "GET /about HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Mar/2026 16:04:10] "GET /static/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Mar/2026 16:04:10] "GET /catalysts HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Mar/2026 16:04:11] "GET /static/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Mar/2026 16:04:11] "GET /static/activated_alumina.jpg HTTP/1.1" 200 -
# ...
